# %%
print("Hello world") # It is the basic sentance of python
# Out:
# Hello world

# %%
if 5 > 2:
    print("five is greater than two") # It is the If statment in python
# Out:
# five is greater than two

# %%
x = 5   # variable declaration
y  = "Hellow world"
print(x)
print(y)
# Out:
# 5
# Hellow world

# %%
#A computer program is a list of "instructions" to be "executed" by a computer.

#In a programming language, these programming instructions are called statements.
print("python is fun")
# Out:
# python is fun

# %%
# Python output
print("Hellow world")
print("I am learning python.")
print("It is awosome")
# Out:
# Hellow world
# I am learning python.
# It is awosome

# %%
#Text in Python must be inside quotes. You can use either " double quotes or ' single quotes:
print("Hellow world")
print("I am learning python.")
print('It is awosome')
# Out:
# Hellow world
# I am learning python.
# It is awosome

# %%
# If we forget quotes or double quotes pthon will give an error
print(I am leaning python)

# %%
#By default, the print() function ends with a new line.

#If you want to print multiple words on the same line, you can use the end parameter:
print("Hello World!", end=" ")
print("I will print on the same line.")
# Out:
# Hello World! I will print on the same line.

# %%
print("hellow world",end=" ")
print("I will print on same line")
# Out:
# hellow world I will print on same line

# %%
print("Hello world", end=" ")
print("my name is ikram")
# Out:
# Hello world my name is ikram

# %%
# print out numbers
#Print Numbers
#You can also use the print() function to display numbers:
#However, unlike text, we don't put numbers inside double quotes:
print(200)
print(4500)
print(6500)
# Out:
# 200
# 4500
# 6500

# %%
# You can also do math inside the print() function:
print(6*8)
print(6//2) # Duble Slash is used for an integers
# Out:
# 48
# 3

# %%
# There ara three numeric types in python. Int, float, and complex
x = 6 # it is integer
y = 3.5 # its a float number
z = 5j # It is a complex number
print(x)
print(y)
print(z)
# Out:
# 6
# 3.5
# 5j

# %%
# Typecasting: To convert one data type to another
a = float(x)
b = int(y)
print(a)
print(b)
# Out:
# 6.0
# 3

# %%
#Import the random module, and display a random number from 1 to 9:
import random
print(random.randrange(1,10))
# Out:
# 7

# %%
# quat inside a quat
print("It's alright")
print("He is called 'Johnny'")
print('He is called "Johnny"')
print('My name is "Ikram"')
# Out:
# It's alright
# He is called 'Johnny'
# He is called "Johnny"
# My name is "Ikram"
